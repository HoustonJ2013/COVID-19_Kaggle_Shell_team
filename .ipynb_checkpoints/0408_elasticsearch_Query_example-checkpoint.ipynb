# %%
import logging
from elasticsearch import Elasticsearch, helpers
import pandas as pd
from elasticsearch_helpers import query_key_words_phrases, es_equery

es = Elasticsearch(
    hosts=[{"hosts":"localhost", "port":9200}], 
    request_timeout=12000)
index_name = "covid-kaggle"
doc_type = "pdf_json"
# Out:
# /home/jingbo/anaconda3/envs/realestatestudy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# There are 52097 of json files

# %% [markdown]
# ## Test query ES

# %%
current_task="risk factor~"
kewords = ["smoking~", "preganacy~2"]
keyphrases = ["risk factor~"]

## Generate es query
es_query = query_key_words_phrases(keywords=kewords, keyphrases=keyphrases, task=current_task)

## Query and return pandas dataframe
q1_df = es_equery(es, es_query, index=index_name, doc_type=doc_type, )
q1_df
# Out:
# There are 22 of papers returned
#                                     paper_id  match_scores publish_years  \
# 0   48656efc59191537073975938f25f201524971af     36.016712          2020
# 1   b696d208705fcb1925693c5f0d118733bb557ea6     30.448978          2020
# 2   5d3612cd95331a2f0c43ef9d03ce583b5ff8c995     27.408878          2020
# 3   e9457327ddb51cf3ceb3698660ff08f526a09d44     27.153708          2020
# 4   5129bb31949c66ebd544658c531004046d4102da     26.480953          2020
# 5   62d68fb65591e60de58891c42f5a1457b9654603     25.057690          2020
# 6                                 PMC7083240     21.140930            -1
# 7   1a48450da54865731ffe01c0e289a63065b3b1fd     19.029669          2020
# 8   7574e8c8c1e0e6df24e6ef15177e2eff23262511     18.379528          2014
# 9   aafa6cdfe96a5cdaf7b7c2f04b11a5dbdd73b2df     17.957909          2020
# 10  79c4b114ab9f9e8070911e38d090446dc700453f     15.267655          2011
# ...
